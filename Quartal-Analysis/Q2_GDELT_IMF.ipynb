# %%
import pandas as pd
import numpy as np
import csv
from google.colab import drive
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from IPython.display import display

# %%
pip install dcor
# Out:
# Collecting dcor
#   Downloading dcor-0.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from dcor) (1.26.4)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.11/dist-packages (from dcor) (0.61.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from dcor) (1.13.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from dcor) (1.4.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51->dcor) (0.44.0)
# Downloading dcor-0.6-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: dcor
# Successfully installed dcor-0.6

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
gdelt = pd.read_csv('/content/drive/MyDrive/DIPLOMSKA/GDELT/dataset2_cleaned.csv')

# %%
gdelt
# Out:
#        GlobalEventID  EventCode  GoldsteinScale    AvgTone  \
# 0         1038625116        144            -7.5  -9.219858
# 1         1038668544        144            -7.5  -3.288672
# 2         1038617615        144            -7.5  -7.886435
# 3         1038628256        144            -7.5 -12.871287
# 4         1038632453        202           -10.0  -1.303116
# ...              ...        ...             ...        ...
# 99552     1038433108        195           -10.0  -0.358423
# 99553     1038419618        195           -10.0  -4.444444
# 99554     1038427251        195           -10.0  -6.187291
# 99555     1038416591        195           -10.0  -4.657017
# 99556     1038453844        195           -10.0  -7.613361
#
#       ActionGeo_CountryCode                                          SOURCEURL
# 0                        US  https://www.msn.com/en-us/news/crime/man-in-cu...
# 1                        US  https://www.businessinsider.com/gofundme-idend...
# 2                        US  https://infotel.ca/newsitem/as-australia-elect...
# 3                        PK  https://www.dawn.com/news/1684242/women-protes...
# 4                        US  https://poststar.com/news/local/fort-salem-the...
# ...                     ...                                                ...
# 99552                    US  https://www.latestly.com/agency-news/india-new...
# 99553                    US  https://www.duluthnewstribune.com/opinion/lett...
# 99554                    US  https://www.philippinetimes.com/news/272463020...
# 99555                    US  https://www.firerescue1.com:443/firefighting-h...
# 99556                    US  http://www.msn.com/en-nz/news/australia/vladim...
#
# [99557 rows x 6 columns]

# %%
imf1 = pd.read_csv('/content/drive/MyDrive/DIPLOMSKA/cleaned_datasetIMF_US.csv')
imf2 = pd.read_csv('/content/drive/MyDrive/DIPLOMSKA/cleaned_datasetIMF_PK.csv')

# %%
gdelt1 = gdelt[gdelt["ActionGeo_CountryCode"] == "US"]["AvgTone"]
gdelt2 = gdelt[gdelt["ActionGeo_CountryCode"] == "PK"]["AvgTone"]

# %%
gdelt2.head(10)
# Out:
# 3     -12.871287
# 9      -9.803922
# 33     -8.648649
# 63     -5.405405
# 64     -2.644552
# 82     -2.503682
# 83     -2.289990
# 84     -2.334337
# 106    -4.347826
# 107   -11.627907
# Name: AvgTone, dtype: float64

# %%
imfUS = imf1.drop(columns=['Country code'])
imfPK = imf2.drop(columns=['Country code'])

# %%
gdelt1 = gdelt1.dropna()
imfUS = imfUS.dropna()
gdelt2 = gdelt2.dropna()
imfPK = imfPK.dropna()

# %%
gdelt1.reset_index(drop=True, inplace=True)
gdelt2.reset_index(drop=True, inplace=True)

# %%
df_transposed = imfUS.T
df_transposed.columns = df_transposed.iloc[0]
df_transposed = df_transposed[1:].reset_index(drop=True)

# %%
df_transposed1 = imfPK.T
df_transposed1.columns = df_transposed1.iloc[0]
df_transposed1 = df_transposed1[1:].reset_index(drop=True)

# %%
important_columns = [
    'Current account', 'Goods and services', 'Total credit', 'Total debit',
    'Net international investment position', 'Direct investment', 'Portfolio investment',
    'Reserve assets', 'Net errors and omissions',
    'Investment income, credit', 'Investment income, debit', 'Financial account',
    'Capital account', 'Secondary income'
]

df_transposed = df_transposed[important_columns]
df_transposed = df_transposed.loc[:, ~df_transposed.columns.duplicated()]

important_columns1 = [
    'Current account', 'Goods and services', 'Total credit', 'Total debit',
    'Net international investment position', 'Direct investment', 'Portfolio investment',
    'Reserve assets', 'Net errors and omissions',
    'Investment income, credit', 'Investment income, debit', 'Financial account',
    'Capital account', 'Secondary income'
]
df_transposed1 = df_transposed1[important_columns1]
df_transposed1 = df_transposed1.loc[:, ~df_transposed1.columns.duplicated()]


df_transposed1.head(10)
# Out:
# Indicator Current account Goods and services Total credit Total debit  \
# 0              -12.216,11         -37.627,11       678,00    6.092,00
# 1               -3.902,08         -10.238,08       145,00    1.436,00
# 2               -4.466,85         -11.583,85       187,00    1.638,00
# 3               -2.441,03          -9.431,03       245,00    1.266,00
# 4               -1.406,15          -6.374,15       101,00    1.752,00
#
# Indicator Net international investment position Direct investment  \
# 0                                   -128.075,19           -305,00
# 1                                   -128.662,82            -91,00
# 2                                   -131.126,71           -496,00
# 3                                   -130.504,39           -353,00
# 4                                   -128.075,19            635,00
#
# Indicator Portfolio investment Reserve assets Net errors and omissions  \
# 0                       714,00     -11.961,31                   194,01
# 1                      -555,00      -5.715,02                    25,03
# 2                       236,00      -1.481,60                   366,29
# 3                        30,00      -2.214,91                    -0,73
# 4                     1.003,00      -2.549,77                  -196,57
#
# Indicator Investment income, credit Investment income, debit  \
# 0                            359,00                 6.064,00
# 1                             76,00                 1.430,00
# 2                             78,00                 1.630,00
# 3                            174,00                 1.259,00
# 4                             31,00                 1.745,00
#
# Indicator Financial account Capital account Secondary income
# 0                -11.616,09          406,00        30.825,00
# 1                 -3.827,05           50,00         7.627,00
# 2                 -4.061,57           39,00         8.568,00
# 3                 -2.407,76           34,00         8.011,00
# 4                 -1.319,72          283,00         6.619,00

# %%
df_transposed1.head(10)
# Out:
# Indicator Current account Goods and services Total credit Total debit  \
# 0              -12.216,11         -37.627,11       678,00    6.092,00
# 1               -3.902,08         -10.238,08       145,00    1.436,00
# 2               -4.466,85         -11.583,85       187,00    1.638,00
# 3               -2.441,03          -9.431,03       245,00    1.266,00
# 4               -1.406,15          -6.374,15       101,00    1.752,00
#
# Indicator Net international investment position Direct investment  \
# 0                                   -128.075,19           -305,00
# 1                                   -128.662,82            -91,00
# 2                                   -131.126,71           -496,00
# 3                                   -130.504,39           -353,00
# 4                                   -128.075,19            635,00
#
# Indicator Portfolio investment Reserve assets Net errors and omissions  \
# 0                       714,00     -11.961,31                   194,01
# 1                      -555,00      -5.715,02                    25,03
# 2                       236,00      -1.481,60                   366,29
# 3                        30,00      -2.214,91                    -0,73
# 4                     1.003,00      -2.549,77                  -196,57
#
# Indicator Investment income, credit Investment income, debit  \
# 0                            359,00                 6.064,00
# 1                             76,00                 1.430,00
# 2                             78,00                 1.630,00
# 3                            174,00                 1.259,00
# 4                             31,00                 1.745,00
#
# Indicator Financial account Capital account Secondary income
# 0                -11.616,09          406,00        30.825,00
# 1                 -3.827,05           50,00         7.627,00
# 2                 -4.061,57           39,00         8.568,00
# 3                 -2.407,76           34,00         8.011,00
# 4                 -1.319,72          283,00         6.619,00

# %%
df_merged1 = pd.merge(gdelt1, df_transposed, left_index=True, right_index=True, how='inner')

# %%
df_merged2 = pd.merge(gdelt2, df_transposed1, left_index=True, right_index=True, how='inner')

# %%
df_merged2.head()
# Out:
#      AvgTone Current account Goods and services Total credit Total debit  \
# 0 -12.871287      -12.216,11         -37.627,11       678,00    6.092,00
# 1  -9.803922       -3.902,08         -10.238,08       145,00    1.436,00
# 2  -8.648649       -4.466,85         -11.583,85       187,00    1.638,00
# 3  -5.405405       -2.441,03          -9.431,03       245,00    1.266,00
# 4  -2.644552       -1.406,15          -6.374,15       101,00    1.752,00
#
#   Net international investment position Direct investment  \
# 0                           -128.075,19           -305,00
# 1                           -128.662,82            -91,00
# 2                           -131.126,71           -496,00
# 3                           -130.504,39           -353,00
# 4                           -128.075,19            635,00
#
#   Portfolio investment Reserve assets Net errors and omissions  \
# 0               714,00     -11.961,31                   194,01
# 1              -555,00      -5.715,02                    25,03
# 2               236,00      -1.481,60                   366,29
# 3                30,00      -2.214,91                    -0,73
# 4             1.003,00      -2.549,77                  -196,57
#
#   Investment income, credit Investment income, debit Financial account  \
# 0                    359,00                 6.064,00        -11.616,09
# 1                     76,00                 1.430,00         -3.827,05
# 2                     78,00                 1.630,00         -4.061,57
# 3                    174,00                 1.259,00         -2.407,76
# 4                     31,00                 1.745,00         -1.319,72
#
#   Capital account Secondary income
# 0          406,00        30.825,00
# 1           50,00         7.627,00
# 2           39,00         8.568,00
# 3           34,00         8.011,00
# 4          283,00         6.619,00

# %%
le = LabelEncoder()

for column in df_merged1.columns:
    if df_merged1[column].dtype == 'object':
        df_merged1[column] = le.fit_transform(df_merged1[column].astype(str))

plt.figure(figsize=(10, 8))
sns.heatmap(df_merged1.corr(), annot=True)
plt.show()

plt.tight_layout()
plt.show()

# %%
le = LabelEncoder()

for column in df_merged2.columns:
    if df_merged2[column].dtype == 'object':
        df_merged2[column] = le.fit_transform(df_merged2[column].astype(str))

plt.figure(figsize=(10, 8))
sns.heatmap(df_merged2.corr(), annot=True)
plt.show()

plt.tight_layout()
plt.show()

# %%
sns.pairplot(df_merged1)
plt.show()

# %%
sns.clustermap(df_merged1.corr(), annot=True, cmap='coolwarm')
plt.title('Кластерска Корелациска Матрица')
plt.show()

# %%
sns.clustermap(df_merged2.corr(), annot=True, cmap='coolwarm')
plt.title('Кластерска Корелациска Матрица')
plt.show()

# %%
corrs = df_merged1.corr()['AvgTone'].drop('AvgTone')
corrs.sort_values().plot(kind='barh', colormap='coolwarm')
plt.xlabel('Корелација')
plt.ylabel('Променливи')
plt.title('Корелации со AvgTone')
plt.show()

# %%
corrs = df_merged2.corr()['AvgTone'].drop('AvgTone')
corrs.sort_values().plot(kind='barh', colormap='coolwarm')
plt.xlabel('Корелација')
plt.ylabel('Променливи')
plt.title('Корелации со AvgTone')
plt.show()

# %%
spearman_corr = df_merged1.corr(method='spearman')
print("Spearman Correlation:\n", spearman_corr)

kendall_corr = df_merged1.corr(method='kendall')
print("\nKendall Correlation:\n", kendall_corr)
# Out:
# Spearman Correlation:
#                                          AvgTone  Current account  \
# AvgTone                                1.000000         0.300000
# Current account                        0.300000         1.000000
# Goods and services                    -0.700000         0.000000
# Total credit                           0.500000         0.100000
# Total debit                            0.500000         0.100000
# Net international investment position  0.718185         0.666886
# Direct investment                      0.100000         0.900000
# Portfolio investment                   0.700000        -0.200000
# Reserve assets                         0.600000        -0.100000
# Net errors and omissions               0.100000         0.100000
# Investment income, credit              0.500000         0.100000
# Investment income, debit               0.500000         0.100000
# Financial account                     -0.100000        -0.600000
# Capital account                        0.400000        -0.100000
# Secondary income                       0.700000         0.200000
#
#                                        Goods and services  Total credit  \
# AvgTone                                         -0.700000      0.500000
# Current account                                  0.000000      0.100000
# Goods and services                               1.000000     -0.900000
# Total credit                                    -0.900000      1.000000
# Total debit                                     -0.900000      1.000000
# Net international investment position           -0.102598     -0.102598
# Direct investment                               -0.100000      0.200000
# Portfolio investment                            -0.200000     -0.100000
# Reserve assets                                  -0.100000     -0.300000
# Net errors and omissions                         0.100000      0.200000
# Investment income, credit                       -0.900000      1.000000
# Investment income, debit                        -0.900000      1.000000
# Financial account                                0.400000     -0.700000
# Capital account                                 -0.600000      0.800000
# Secondary income                                -0.800000      0.900000
#
#                                        Total debit  \
# AvgTone                                   0.500000
# Current account                           0.100000
# Goods and services                       -0.900000
# Total credit                              1.000000
# Total debit                               1.000000
# Net international investment position    -0.102598
# Direct investment                         0.200000
# Portfolio investment                     -0.100000
# Reserve assets                           -0.300000
# Net errors and omissions                  0.200000
# Investment income, credit                 1.000000
# Investment income, debit                  1.000000
# Financial account                        -0.700000
# Capital account                           0.800000
# Secondary income                          0.900000
#
#                                        Net international investment position  \
# AvgTone                                                             0.718185
# Current account                                                     0.666886
# Goods and services                                                 -0.102598
# Total credit                                                       -0.102598
# Total debit                                                        -0.102598
# Net international investment position                               1.000000
# Direct investment                                                   0.410391
# Portfolio investment                                                0.564288
# Reserve assets                                                      0.666886
# Net errors and omissions                                           -0.051299
# Investment income, credit                                          -0.102598
# Investment income, debit                                           -0.102598
# Financial account                                                   0.051299
# Capital account                                                    -0.205196
# Secondary income                                                    0.153897
#
#                                        Direct investment  \
# AvgTone                                         0.100000
# Current account                                 0.900000
# Goods and services                             -0.100000
# Total credit                                    0.200000
# Total debit                                     0.200000
#                                        Secondary income
# AvgTone                                        0.700000
# Current account                                0.200000
# Goods and services                            -0.800000
# Total credit                                   0.900000
# Total debit                                    0.900000
# Net international investment position          0.153897
# Direct investment                              0.100000
# Portfolio investment                           0.200000
# Reserve assets                                -0.100000
# Net errors and omissions                       0.500000
# Investment income, credit                      0.900000
# Investment income, debit                       0.900000
# Financial account                             -0.600000
# Capital account                                0.900000
# Secondary income                               1.000000
#
# Kendall Correlation:
#                                          AvgTone  Current account  \
# AvgTone                                1.000000         0.200000
# Current account                        0.200000         1.000000
# Goods and services                    -0.600000         0.200000
# Total credit                           0.400000         0.000000
# Total debit                            0.400000         0.000000
# Net international investment position  0.527046         0.527046
# Direct investment                      0.000000         0.800000
# Portfolio investment                   0.600000        -0.200000
# Reserve assets                         0.400000         0.000000
# Net errors and omissions               0.000000         0.000000
# Investment income, credit              0.400000         0.000000
# Investment income, debit               0.400000         0.000000
# Financial account                      0.000000        -0.400000
# Capital account                        0.400000         0.000000
# Secondary income                       0.600000         0.200000
#
#                                        Goods and services  Total credit  \
# AvgTone                                         -0.600000      0.400000
# Current account                                  0.200000      0.000000
# Goods and services                               1.000000     -0.800000
# Total credit                                    -0.800000      1.000000
# Total debit                                     -0.800000      1.000000
# Net international investment position           -0.105409     -0.105409
# Direct investment                                0.000000      0.200000
# Portfolio investment                            -0.200000      0.000000
# Reserve assets                                   0.000000     -0.200000
# Net errors and omissions                         0.000000      0.200000
# Investment income, credit                       -0.800000      1.000000
# Investment income, debit                        -0.800000      1.000000
# Financial account                                0.400000     -0.600000
# Capital account                                 -0.400000      0.600000
# Secondary income                                -0.600000      0.800000
#
#                                        Total debit  \
# AvgTone                                   0.400000
# Current account                           0.000000
# Goods and services                       -0.800000
# Total credit                              1.000000
# Total debit                               1.000000
# Net international investment position    -0.105409
# Direct investment                         0.200000
# Portfolio investment                      0.000000
# Reserve assets                           -0.200000
# Net errors and omissions                  0.200000
# Investment income, credit                 1.000000
# Investment income, debit                  1.000000
# Financial account                        -0.600000
# Capital account                           0.600000
# Secondary income                          0.800000
#
#                                        Net international investment position  \
# AvgTone                                                             0.527046
# Current account                                                     0.527046
# Goods and services                                                 -0.105409
# Total credit                                                       -0.105409
# Total debit                                                        -0.105409
# Net international investment position                               1.000000
# Direct investment                                                   0.316228
# Portfolio investment                                                0.316228
# Reserve assets                                                      0.527046
# Net errors and omissions                                            0.105409
# Investment income, credit                                          -0.105409
# Investment income, debit                                           -0.105409
# Financial account                                                   0.105409
# Capital account                                                    -0.105409
# Secondary income                                                    0.105409
#
#                                        Direct investment  \
# AvgTone                                         0.000000
# Current account                                 0.800000
# Goods and services                              0.000000
# Total credit                                    0.200000
# Total debit                                     0.200000
# Net international investment position           0.316228
# Direct investment                               1.000000
# Portfolio investment                           -0.400000
# Reserve assets                                 -0.200000
# Net errors and omissions                       -0.200000
# Investment income, credit                       0.200000
# Investment income, debit                        0.200000
# Financial account                              -0.600000
# Net errors and omissions                       0.400000
# Investment income, credit                      0.800000
# Investment income, debit                       0.800000
# Financial account                             -0.400000
# Capital account                                0.800000
# Secondary income                               1.000000

# %%
spearman_corr = df_merged2.corr(method='spearman')
print("Spearman Correlation:\n", spearman_corr)

kendall_corr = df_merged2.corr(method='kendall')
print("\nKendall Correlation:\n", kendall_corr)
# Out:
# Spearman Correlation:
#                                          AvgTone  Current account  \
# AvgTone                                1.000000        -0.300000
# Current account                       -0.300000         1.000000
# Goods and services                     0.600000        -0.600000
# Total credit                          -0.600000         0.100000
# Total debit                           -0.300000        -0.500000
# Net international investment position  0.102598         0.872082
# Direct investment                      0.600000        -0.100000
# Portfolio investment                  -0.300000        -0.200000
# Reserve assets                         0.200000        -0.300000
# Net errors and omissions              -0.500000         0.700000
# Investment income, credit             -0.500000         0.700000
# Investment income, debit              -0.300000        -0.500000
# Financial account                     -0.300000         1.000000
# Capital account                       -0.900000         0.500000
# Secondary income                       0.300000         0.800000
#
#                                        Goods and services  Total credit  \
# AvgTone                                          0.600000     -0.600000
# Current account                                 -0.600000      0.100000
# Goods and services                               1.000000      0.200000
# Total credit                                     0.200000      1.000000
# Total debit                                     -0.100000      0.100000
# Net international investment position           -0.153897      0.102598
# Direct investment                               -0.200000     -1.000000
# Portfolio investment                             0.500000      0.900000
# Reserve assets                                  -0.100000     -0.600000
# Net errors and omissions                        -0.900000     -0.100000
# Investment income, credit                       -0.900000     -0.100000
# Investment income, debit                        -0.100000      0.100000
# Financial account                               -0.600000      0.100000
# Capital account                                 -0.800000      0.300000
# Secondary income                                -0.100000     -0.100000
#
#                                        Total debit  \
# AvgTone                                  -0.300000
# Current account                          -0.500000
# Goods and services                       -0.100000
# Total credit                              0.100000
# Total debit                               1.000000
# Net international investment position    -0.666886
# Direct investment                        -0.100000
# Portfolio investment                      0.300000
# Reserve assets                           -0.300000
# Net errors and omissions                  0.200000
# Investment income, credit                 0.200000
# Investment income, debit                  1.000000
# Financial account                        -0.500000
# Capital account                           0.000000
# Secondary income                         -0.700000
#
#                                        Net international investment position  \
# AvgTone                                                             0.102598
# Current account                                                     0.872082
# Goods and services                                                 -0.153897
# Total credit                                                        0.102598
# Total debit                                                        -0.666886
# Net international investment position                               1.000000
# Direct investment                                                  -0.102598
# Portfolio investment                                               -0.051299
# Reserve assets                                                     -0.410391
# Net errors and omissions                                            0.359092
# Investment income, credit                                           0.359092
# Investment income, debit                                           -0.666886
# Financial account                                                   0.872082
# Capital account                                                     0.051299
# Secondary income                                                    0.974679
#
#                                        Direct investment  \
# AvgTone                                         0.600000
# Current account                                -0.100000
# Goods and services                             -0.200000
# Total credit                                   -1.000000
# Total debit                                    -0.100000
# Net international investment position          -0.102598
# Direct investment                               1.000000
# Portfolio investment                           -0.900000
# Reserve assets                                  0.600000
# Net errors and omissions                        0.100000
# Investment income, credit                       0.100000
# Investment income, debit                       -0.100000
# Financial account                              -0.100000
# Capital account                                -0.300000
# Secondary income                                0.100000
#
#                                        Portfolio investment  Reserve assets  \
# AvgTone                                           -0.300000        0.200000
# Current account                                   -0.200000       -0.300000
# Goods and services                                 0.500000       -0.100000
# Total credit                                       0.900000       -0.600000
# Total debit                                        0.300000       -0.300000
# Net international investment position             -0.051299       -0.410391
# Direct investment                                 -0.900000        0.600000
# Portfolio investment                               1.000000       -0.700000
# Reserve assets                                    -0.700000        1.000000
# Net errors and omissions                          -0.300000       -0.300000
# Investment income, credit                         -0.300000       -0.300000
# Investment income, debit                           0.300000       -0.300000
# Financial account                                 -0.200000       -0.300000
# Capital account                                   -0.100000        0.100000
# Secondary income                                  -0.200000       -0.300000
#
#                                        Net errors and omissions  \
# AvgTone                                               -0.500000
# Current account                                        0.700000
# Goods and services                                    -0.900000
# Total credit                                          -0.100000
# Total debit                                            0.200000
# Net international investment position                  0.359092
# Direct investment                                      0.100000
# Portfolio investment                                  -0.300000
# Reserve assets                                        -0.300000
# Net errors and omissions                               1.000000
# Investment income, credit                              1.000000
# Investment income, debit                               0.200000
# Financial account                                      0.700000
# Capital account                                        0.600000
# Secondary income                                       0.300000
#
#                                        Investment income, credit  \
# AvgTone                                                -0.500000
# Current account                                         0.700000
# Goods and services                                     -0.900000
# Total credit                                           -0.100000
# Total debit                                             0.200000
# Net international investment position                   0.359092
# Direct investment                                       0.100000
# Portfolio investment                                   -0.300000
# Reserve assets                                         -0.300000
# Net errors and omissions                                1.000000
# Investment income, credit                               1.000000
# Investment income, debit                                0.200000
# Financial account                                       0.700000
# Capital account                                         0.600000
# Secondary income                                        0.300000
#
#                                        Investment income, debit  \
# AvgTone                                               -0.300000
# Current account                                       -0.500000
# Goods and services                                    -0.100000
# Total credit                                           0.100000
# Total debit                                            1.000000
# Net international investment position                 -0.666886
# Direct investment                                     -0.100000
# Portfolio investment                                   0.300000
# Reserve assets                                        -0.300000
# Net errors and omissions                               0.200000
# Investment income, credit                              0.200000
# Investment income, debit                               1.000000
# Financial account                                     -0.500000
# Capital account                                        0.000000
# Secondary income                                      -0.700000
#
#                                        Financial account  Capital account  \
# AvgTone                                        -0.300000        -0.900000
# Current account                                 1.000000         0.500000
# Goods and services                             -0.600000        -0.800000
# Total credit                                    0.100000         0.300000
# Total debit                                    -0.500000         0.000000
# Net international investment position           0.872082         0.051299
# Direct investment                              -0.100000        -0.300000
# Portfolio investment                           -0.200000        -0.100000
# Reserve assets                                 -0.300000         0.100000
# Net errors and omissions                        0.700000         0.600000
# Investment income, credit                       0.700000         0.600000
# Investment income, debit                       -0.500000         0.000000
# Financial account                               1.000000         0.500000
# Capital account                                 0.500000         1.000000
# Secondary income                                0.800000        -0.100000
#
#                                        Secondary income
# AvgTone                                        0.300000
# Current account                                0.800000
# Goods and services                            -0.100000
# Total credit                                  -0.100000
# Total debit                                   -0.700000
# Net international investment position          0.974679
# Direct investment                              0.100000
# Portfolio investment                          -0.200000
numeric_columns = df_merged1.select_dtypes(include=['number']).columns
numeric_columns = numeric_columns.drop('AvgTone', errors='ignore')

results = {}
for col in numeric_columns:
    corr_value = distance_correlation(df_merged1['AvgTone'], df_merged1[col])
    results[col] = corr_value

sorted_results = sorted(results.items(), key=lambda x: abs(x[1]), reverse=True)
for col, value in sorted_results:
    print(f"Distance Correlation between AvgTone and {col}: {value:.4f}")
# Out:
# Distance Correlation between AvgTone and Goods and services: 0.9036
# Distance Correlation between AvgTone and Secondary income: 0.7333
# Distance Correlation between AvgTone and Portfolio investment: 0.7278
# Distance Correlation between AvgTone and Total credit: 0.6803
# Distance Correlation between AvgTone and Total debit: 0.6803
# Distance Correlation between AvgTone and Investment income, credit: 0.6803
# Distance Correlation between AvgTone and Investment income, debit: 0.6803
# Distance Correlation between AvgTone and Reserve assets: 0.6784
# Distance Correlation between AvgTone and Capital account: 0.6695
# Distance Correlation between AvgTone and Net errors and omissions: 0.6578
# Distance Correlation between AvgTone and Net international investment position: 0.6558
# Distance Correlation between AvgTone and Direct investment: 0.6053
# Distance Correlation between AvgTone and Financial account: 0.5996
# Distance Correlation between AvgTone and Current account: 0.5996
# /usr/local/lib/python3.11/dist-packages/dcor/_fast_dcov_avl.py:554: UserWarning: Falling back to uncompiled AVL fast distance covariance terms because of TypeError exception raised: No matching definition for argument type(s) array(float64, 1d, C), array(int64, 1d, C), bool. Rembember: only floating point values can be used in the compiled implementations.
#   warnings.warn(

# %%
numeric_columns = df_merged2.select_dtypes(include=['number']).columns
numeric_columns = numeric_columns.drop('AvgTone', errors='ignore')

results = {}
for col in numeric_columns:
    corr_value = distance_correlation(df_merged2['AvgTone'], df_merged2[col])
    results[col] = corr_value


sorted_results = sorted(results.items(), key=lambda x: abs(x[1]), reverse=True)
for col, value in sorted_results:
    print(f"Distance Correlation between AvgTone and {col}: {value:.4f}")
# Out:
# Distance Correlation between AvgTone and Capital account: 0.9387
# Distance Correlation between AvgTone and Goods and services: 0.8214
# Distance Correlation between AvgTone and Net errors and omissions: 0.8139
# Distance Correlation between AvgTone and Investment income, credit: 0.8139
# Distance Correlation between AvgTone and Total credit: 0.7153
# Distance Correlation between AvgTone and Direct investment: 0.7153
# Distance Correlation between AvgTone and Current account: 0.7106
# Distance Correlation between AvgTone and Financial account: 0.7106
# Distance Correlation between AvgTone and Secondary income: 0.6527
# Distance Correlation between AvgTone and Total debit: 0.6509
# Distance Correlation between AvgTone and Investment income, debit: 0.6509
# Distance Correlation between AvgTone and Portfolio investment: 0.6336
# Distance Correlation between AvgTone and Reserve assets: 0.6283
# Distance Correlation between AvgTone and Net international investment position: 0.5511
# /usr/local/lib/python3.11/dist-packages/dcor/_fast_dcov_avl.py:554: UserWarning: Falling back to uncompiled AVL fast distance covariance terms because of TypeError exception raised: No matching definition for argument type(s) array(float64, 1d, C), array(int64, 1d, C), bool. Rembember: only floating point values can be used in the compiled implementations.
#   warnings.warn(

# %%
from sklearn.feature_selection import mutual_info_regression

X = df_merged1['AvgTone'].values.reshape(-1, 1)


mi_dict = {}

for column in df_merged1.columns:
    if column != 'AvgTone':
        y = df_merged1[column]
        mi = mutual_info_regression(X, y)
        mi_dict[column] = mi[0]

sorted_mi = sorted(mi_dict.items(), key=lambda x: x[1], reverse=True)
for feature, mi_value in sorted_mi:
    print(f"Mutual Information between AvgTone and {feature}: {mi_value}")
# Out:
# Mutual Information between AvgTone and Secondary income: 0.13333333333333353
# Mutual Information between AvgTone and Direct investment: 0.06666666666666687
# Mutual Information between AvgTone and Capital account: 0.01666666666666683
# Mutual Information between AvgTone and Current account: 2.220446049250313e-16
# Mutual Information between AvgTone and Portfolio investment: 2.220446049250313e-16
# Mutual Information between AvgTone and Financial account: 2.220446049250313e-16
# Mutual Information between AvgTone and Goods and services: 0
# Mutual Information between AvgTone and Total credit: 0
# Mutual Information between AvgTone and Total debit: 0
# Mutual Information between AvgTone and Net international investment position: 0
# Mutual Information between AvgTone and Reserve assets: 0
# Mutual Information between AvgTone and Net errors and omissions: 0
# Mutual Information between AvgTone and Investment income, credit: 0
# Mutual Information between AvgTone and Investment income, debit: 0

# %%
X = df_merged2['AvgTone'].values.reshape(-1, 1)

mi_dict = {}


for column in df_merged2.columns:
    if column != 'AvgTone':
        y = df_merged2[column]
        mi = mutual_info_regression(X, y)
        mi_dict[column] = mi[0]


sorted_mi = sorted(mi_dict.items(), key=lambda x: x[1], reverse=True)
for feature, mi_value in sorted_mi:
    print(f"Mutual Information between AvgTone and {feature}: {mi_value}")
# Out:
# Mutual Information between AvgTone and Direct investment: 0.1166666666666667
# Mutual Information between AvgTone and Capital account: 0.06666666666666687
# Mutual Information between AvgTone and Total credit: 0.050000000000000266
# Mutual Information between AvgTone and Current account: 2.220446049250313e-16
# Mutual Information between AvgTone and Net international investment position: 2.220446049250313e-16
# Mutual Information between AvgTone and Portfolio investment: 2.220446049250313e-16
# Mutual Information between AvgTone and Financial account: 2.220446049250313e-16
# Mutual Information between AvgTone and Secondary income: 2.220446049250313e-16
# Mutual Information between AvgTone and Goods and services: 0
# Mutual Information between AvgTone and Total debit: 0
# Mutual Information between AvgTone and Reserve assets: 0
# Mutual Information between AvgTone and Net errors and omissions: 0
# Mutual Information between AvgTone and Investment income, credit: 0
# Mutual Information between AvgTone and Investment income, debit: 0

# %%
sns.violinplot(y=df_merged1["AvgTone"])
plt.title("Distribution of AvgTone")
plt.show()

# %%
sns.violinplot(y=df_merged2["AvgTone"])
plt.title("Distribution of AvgTone")
plt.show()

# %%
sns.histplot(df_merged1["AvgTone"], bins=20, kde=True, color="blue")
plt.title("Distribution of AvgTone")
plt.xlabel("AvgTone")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(df_merged2["AvgTone"], bins=20, kde=True, color="blue")
plt.title("Distribution of AvgTone")
plt.xlabel("AvgTone")
plt.ylabel("Frequency")
plt.show()
